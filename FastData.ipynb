# %%
import seaborn as sns
import matplotlib.transforms as transforms
from datetime import datetime
from skimage.io import imsave
import openpyxl
import numpy as np
import matplotlib.pyplot as plt
#%plt.style.use("v_paper")
import pandas as pd
#import deepdish as dd
from scipy.io import loadmat
# %matplotlib inline
import seaborn as sns
import statsmodels.formula.api as smf
import re
from statsmodels.stats.anova import anova_lm
import os
import os.path
import statsmodels.api as smapi
import sys
import warnings
from sklearn.linear_model import LinearRegression
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import seaborn as sns
import statsmodels as sm
import scipy
from pathlib import Path
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.stats.api as sms

# %%
df=Regionsdf.query('FR>=30')

# %%
Regionsdf=pd.read_pickle("Regionsdf.pkl")

# %%
df.expID.unique()
# Out:
# array(['216', '100761', '100762', '103', '104', '105', '100106', 'B43',
#        'B180', 'B193', 'B194', 'B195', 'B197', '100234', '100609', '981',
#        '100133', '100160', 'B127', 'B128', 'B129', 'B131', 'B132', 'B133',
#        'B134', '107', '100142', '100145', '100455', '100597', '100621',
#        '46', '47', 'B765', 'B766', 'B767', 'B768', '29', '158', 'B123',
#        'B124', 'B158'], dtype=object)

# %%
Regionsdf.query('expID=="B124"')
# Out:
#      index                                                  0  FlyID  \
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# ..     ...                                                ...    ...
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
# 209     45  /media/NAS/Sophie/WalkProject/Trh/B122-B124/B1...     94
#
#                                           Templatefile  \
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# ..                                                 ...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...
#
#                                                 TSfile expID UAS GAL4  \
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# ..                                                 ...   ...  ..  ...
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
# 209  /media/NAS/Sophie/WalkProject/Trh/B122-B124/Da...  B124  6m  Trh
#
#                                         Correspondance  \
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# ..                                                 ...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
# 209   , , ,ATL,AVLPm,AVLPm, , , ,AVLPshell,AVLPshel...
#
#                                             RegionFile  ... R2Groom CoefGroom  \
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# ..                                                 ...  ...     ...       ...
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
# 209  Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\...  ...     NaN       NaN
#
#     R2Flail CoefFlail CoefForcedWalk R2ForcedWalk  R2ForcedTurn_ipsi  \
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# ..      ...       ...            ...          ...                ...
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
# 209     NaN       NaN            NaN          NaN                NaN
#
#      R2ForcedTurn_contra  R2ForcedIpsi_contra  R2Forcedipsi_R2contra
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# ..                   ...                  ...                    ...
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
# 209                  NaN                  NaN                    NaN
#
# [75 rows x 61 columns]
