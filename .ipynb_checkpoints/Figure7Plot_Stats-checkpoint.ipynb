# %%
import seaborn as sns

from datetime import datetime
from skimage.io import imsave
import openpyxl
import numpy as np
import matplotlib.pyplot as plt
#%plt.style.use("v_paper")
import pandas as pd
import deepdish as dd
from scipy.io import loadmat
# %matplotlib inline
import seaborn as sns
import statsmodels.formula.api as smf
import re
from statsmodels.stats.anova import anova_lm
import os
import os.path
import statsmodels.api as smapi
import sys
import warnings
from sklearn.linear_model import LinearRegression
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import seaborn as sns
import qgrid
import statsmodels as sm
import scipy
from pathlib import Path
# Out:
# C:\Users\aimon\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
Compdf=pd.read_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\Compdf.pkl")

# %%
Compdf.iloc[511]
# Out:
# level_0                                                                  3
# index                                                                   15
# 0                        /media/NAS/Sophie/WalkProject/Pan-NeuronalCalc...
# FlyID                                                                    4
# Templatefile             /media/NAS/Sophie/WalkProject/Pan-NeuronalCalc...
# TSfile                   /media/NAS/Sophie/WalkProject/Pan-NeuronalCalc...
# expID                                                               100761
# UAS                                                                     7s
# GAL4                                                              GMR57C10
# Correspondance           GNGml,IPS-Y,IPS-Y,PRW,PENP,LAL-GNG,WE-AMMC, ,W...
# RegionFile               Z:\GrunwaldKadow_group\Sophie\WalkProject\Pan-...
# WalkRegressor            Z:\GrunwaldKadow_group\Sophie\WalkProject\Pan-...
# GroomRegressor           Z:\GrunwaldKadow_group\Sophie\WalkProject\Pan-...
# FlailRegressor
# TurnRegressor
# ForcedWalkRegressor                                                    NaN
# ForcedTurnRegressor                                                    NaN
# FR                                                                     100
# TSlowlimForced                                                         NaN
# TShighlimForced                                                        NaN
# TSlowlimFlail                                                          NaN
# TShighlimFlail                                                         NaN
# TSlowlimWalk                                                           NaN
# TShighlimWalk                                                          NaN
# eye_painted                                                          False
# CompID                                                             AMMC-WE
# CompNum                                                                  6
# CoefWalk                                                        0.00388262
# R2Walk                                                           0.0158204
# CoefTurn_ipsi                                                          NaN
# R2Turn_ipsi                                                            NaN
# CoefTurn_contra                                                        NaN
# CoefIpsi-contra                                                        NaN
# R2Turn_contra                                                          NaN
# R2Ipsi-contra                                                          NaN
# L_R                                                                    NaN
# R2ipsi-R2contra                                                        NaN
# Coefipsi-Coefcontra                                                    NaN
# CoefForcedTurn_ipsi                                                    NaN
# R2ForcedTurn_ipsi                                                      NaN
# CoefForcedTurn_contra                                                  NaN
# R2ForcedTurn_contra                                                    NaN
# CoefGroom                                                        0.0339188
# R2Groom                                                           0.693924
# CoefForcedWalk                                                         NaN
# R2ForcedWalk                                                           NaN
# CoefFlail                                                              NaN
# R2Flail                                                                NaN
# Name: 511, dtype: object

# %%
Regionsdf=pd.read_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\Regionsdf.pkl")

# %%
GoodICFiles=pd.read_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\GoodICsdf.pkl")

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllWalkPAN.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
result = smf.ols(formula="CoefWalk ~ UAS+GAL4+RegionNames+FR+eye_painted", data=Regionsdf).fit()
aov_table = anova_lm(result, typ=2)
print(result.rsquared)
aov_table
# Out:
# 0.5270628476208774
#                 sum_sq      df            F         PR(>F)
# UAS          23.655357     5.0    97.041163   1.180225e-74
# GAL4         51.930028     7.0   152.165785   1.171989e-61
# RegionNames  15.603872    40.0     8.001453   5.346934e-41
# eye_painted   8.080516     1.0   165.743156   2.639538e-36
# FR           61.013486     1.0  1251.475427  2.714374e-207
# Residual     85.366929  1751.0          NaN            NaN

# %%
df=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
df2=df[['R2Walk','RegionNum','RegionNames']]
df2=df2.dropna()
file='Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2AllWalkPAN.txt'
df=df2
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2AllWalkPAN.txt', 'w') as f:
    for j in range(75):
        df2=df.loc[df['RegionNum']==j]
        #f.write(compid)

        f.write(str(np.median(df.loc[df['RegionNames']==list(df2['RegionNames'])[0],'R2Walk'])))        
        f.write('\n')
        
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\ListR2Files.txt', 'a') as f:
    f.write(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))        
    f.write('\n') 
    print(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))
# Out:
# /media/NAS/Sophie/WalkProject/Figures/Figure1/MedianR2AllWalkPAN.txt

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsPANWalk.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
pvalcorr[1][i]
# Out:
# 4.263216779598622e-08

# %%
df=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
df2=df[['CoefWalk','RegionNames','FlyID']]
df2=df2.dropna()
L=len(df2.RegionNames.unique())
df=df2
pval=np.zeros(41)

i=0
for compid in df.RegionNames.unique():
    df2=df.loc[df['RegionNames']==compid]
    pval[i]=scipy.stats.wilcoxon(df2.groupby('FlyID').mean()['CoefWalk']).pvalue
    i=i+1
    
pvalcorr=sm.stats.multitest.multipletests(pval, alpha=0.05, method='hs', is_sorted=False, returnsorted=False)

i=0
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefAllWalkPANtoZeropval.txt', 'w') as f:
    for compid in df.RegionNames.unique():
        f.write(compid)
        f.write(':') 
        f.write(str(pvalcorr[1][i]))        
        f.write('\n')
        print(compid)
        print(pvalcorr[1][i])
        i=i+1
# Out:
Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
df2=df[['CoefGroom','RegionNames','FlyID']]
df2=df2.dropna()
L=len(df2.RegionNames.unique())
df=df2
pval=np.zeros(41)

i=0
for compid in df.RegionNames.unique():
    df2=df.loc[df['RegionNames']==compid]
    pval[i]=scipy.stats.wilcoxon(df2.groupby('FlyID').mean()['CoefGroom']).pvalue
    i=i+1
    
pvalcorr=sm.stats.multitest.multipletests(pval, alpha=0.05, method='hs', is_sorted=False, returnsorted=False)

i=0
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefAllGroomPANtoZeropval.txt', 'w') as f:
    for compid in df.RegionNames.unique():
        f.write(compid)
        f.write(':') 
        f.write(str(pvalcorr[1][i]))        
        f.write('\n')
        print(compid)
        print(pvalcorr[1][i])
        i=i+1
# Out:
# AME
# 0.9999999992300995
# LO
# 0.9999999992300995
# NO
# 0.9999999992300995
# BU
# 0.8574307101195819
# PB
# 0.9999999992300995
# LH
# 0.955266176368296
# LAL
# 0.9999926138158288
# SAD
# 0.9989258854362367
# CAN
# 0.999974961307696
# AMMC
# 0.999894562091953
# ICL
# 0.9917873481721482
# VES
# 0.999894562091953
# IB
# 0.9999999992300995
# ATL
# 0.9999999992300995
# CRE
# 0.9917873481721482
# MBPED
# 0.999894562091953
# MBVL
# 0.9999999992300995
# MBML
# 0.999894562091953
# FLA
# 0.999974961307696
# LOP
# 0.9999999318334531
# EB
# 0.9999999318334531
# AL
# 0.9999999992300995
# ME
# 0.999974961307696
# FB
# 0.9999999318334531
# SLP
# 0.999894562091953
# SIP
# 0.9999999992300995
# SMP
# 0.9999999992300995
# AVLP
# 0.9999999992300995
# PVLP
# 0.9999999992300995
# IVLP
# 0.9989258854362367
# PLP
# 0.9989258854362367
# AOTU
# 0.999974961307696
# GOR
# 0.9999999992300995
# MBCA
# 0.999974961307696
# SPS
# 0.999974961307696
# IPS
# 0.9989258854362367
# SCL
# 0.999894562091953
# EPA
# 0.9999999992300995
# GNG
# 0.9917873481721482
# PRW
# 0.999894562091953
# GA
# 0.9999999992300995

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Flail',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllFlail.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='CoefGroom',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsPANGroom.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.query('GAL4=="Nsyb" or GAL4=="GMR57C10"')
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Groom',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    # iterate over whiskers and median lines
    for j in range(6*i,6*(i+1)):
         b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsPANGroom.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
df4=df3.loc[df3['RegionNames']=='FB']
df4.loc[df4['R2Groom']>0,'UAS']
# Out:
# 1     7f
# 3     7s
# 21    6m
# 29    6m
# 41    6f
# 50    6s
# Name: UAS, dtype: object

# %%
df4.loc[df4['R2Groom']>0,'expID']
# Out:
# 1        244
# 3     100761
# 21       B42
# 29      B192
# 41    100148
# 50    100133
# Name: expID, dtype: object

# %%
df4=df3.loc[df3['RegionNames']=='FB']
df4.loc[df4['R2Flail']>0,'UAS']
# Out:
# 21    6m
# 26    6m
# 28    6m
# 29    6m
# 57    6s
# 93    7f
# Name: UAS, dtype: object

# %%
df4.loc[df4['R2Flail']>0,'expID']
# Out:
# 21        B42
# 26       B183
# 28       B190
# 29       B192
# 57      B1037
# 93    KC00060
# Name: expID, dtype: object

# %%
df4=df3.loc[df3['RegionNames']=='FB']
df4.loc[df4['R2Walk']>0,'UAS']
# Out:
# 3     7s
# 8     6m
# 9     6m
# 13    6m
# 14    6m
# 15    6m
# 16    6m
# 20    6m
# 21    6m
# 22    6m
# 24    6m
# 25    6m
# 26    6m
# 29    6m
# 30    6m
# 31    6m
# 32    6m
# 33    6m
# 41    6f
# 42    6f
# 44    6f
# 50    6s
# 53    7s
# 57    6s
# 64    6s
# Name: UAS, dtype: object

# %%
df4.loc[df4['R2Groom']>0,'expID']
# Out:
# 1        244
# 3     100761
# 21       B42
# 29      B192
# 41    100148
# 50    100133
# Name: expID, dtype: object

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))

df3=Regionsdf
#df2=Regionsdf.loc[Regionsdf['GAL4']=='Nsyb']
#df3=df2.loc[df2['UAS']=='6m']
#df3=df2.dropna()
b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='m')
b = sns.boxplot(x='RegionNames',y='R2Flail',data=df3,color='g')

    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllFlailg_Walkm.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))

df3=Regionsdf
#df2=Regionsdf.loc[Regionsdf['GAL4']=='Nsyb']
#df3=df2.loc[df2['UAS']=='6m']
#df3=df2.dropna()
b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df3,color='m')
b = sns.boxplot(x='RegionNames',y='CoefFlail',data=df3,color='g')

    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsAllFlailg_Walkm.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
df=Regionsdf
df['R2']=np.nan
df.loc[df['R2Walk']!=0,'R2']=df.loc[df['R2Walk']!=0,'R2Walk']
df.loc[df['R2Flail']!=0,'R2']=df.loc[df['R2Flail']!=0,'R2Flail']
df.loc[df['R2Groom']!=0,'R2']=df.loc[df['R2Groom']!=0,'R2Groom']

# %%
df_meltedR2 = df.melt( id_vars=['UAS','GAL4','RegionNames','FR','FlyID'],value_vars=['R2Walk', 'R2Flail','R2Groom'],var_name='Behavior',value_name='R2')
df_meltedCoef = df.melt( id_vars=['UAS','GAL4','RegionNames','FR','FlyID'],value_vars=['CoefWalk', 'CoefFlail','CoefGroom'],var_name='Behavior',value_name='Coef')

# %%
ax=sns.boxplot(x='Behavior',y='R2',data=df_meltedR2,color='w')
# for j in range(6):
#     ax.lines[j].set_color('black')
# for i,violin in enumerate(ax.artists):
#     violin.set_edgecolor('black')
#     box.set_facecolor('white')
plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\BoxR2RegionsAllBehaviorpis1_10-17inanova.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5e9d3fb9cfff> in <module>
# ----> 1 ax=sns.boxplot(x='Behavior',y='R2',data=df_meltedR2,color='w')
#       2 # for j in range(6):
#       3 #     ax.lines[j].set_color('black')
#       4 # for i,violin in enumerate(ax.artists):
#       5 #     violin.set_edgecolor('black')
#
# NameError: name 'df_meltedR2' is not defined

# %%
ax=sns.violinplot(x='Behavior',y='R2',data=df_meltedR2,color='w')
for j in range(6):
    ax.lines[j].set_color('black')
for i,violin in enumerate(ax.artists):
    violin.set_edgecolor('black')
    box.set_facecolor('white')
plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllBehaviorpis1_10-17inanova.svg')

# %%
dfWalkR2=df_meltedR2.loc[df_meltedR2['Behavior']=='R2Walk'].groupby('FlyID').mean()
dfFlailR2=df_meltedR2.loc[df_meltedR2['Behavior']=='R2Flail'].groupby('FlyID').mean()
dfGroomR2=df_meltedR2.loc[df_meltedR2['Behavior']=='R2Groom'].groupby('FlyID').mean()

# %%
sns.violinplot(y='R2',data=dfWalkR2,color='w')
sns.violinplot(y='R2',data=dfFlailR2,color='b')
sns.violinplot(y='R2',data=dfGroomR2,color='r')

# %%
sns.violinplot(y='R2',data=dfWalkR2,color='w')
sns.violinplot(y='R2',data=dfFlailR2,color='b')
sns.violinplot(y='R2',data=dfGroomR2,color='r')

# %%
len(dfFlailR2.loc[dfFlailR2['R2']>0]['R2'])
# Out:
# 15

# %%
len(dfGroomR2.loc[dfGroomR2['R2']>0]['R2'])
# Out:
# 6

# %%
list(dfGroomR2.loc[dfGroomR2['R2']>0]['R2'])
# Out:
# [0.01657549735375843,
#  0.2612928522116894,
#  0.002109099473632809,
#  0.004024315060501761,
#  0.08070262754902463,
#  0.013738317904386819]

# %%
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\BehaviorPairR2_pvaluesperfly.txt', 'w') as f:

        f.write('Walk vs Flail')
        f.write(':') 
        f.write("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfWalkR2.loc[dfWalkR2['R2']>0]['R2'], dfFlailR2.loc[dfFlailR2['R2']>0]['R2']).pvalue*3))        
        f.write('\n')
        print("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfWalkR2.loc[dfWalkR2['R2']>0]['R2'], dfFlailR2.loc[dfFlailR2['R2']>0]['R2']).pvalue*3))

        f.write('Walk vs Groom')
        f.write(':') 
        f.write("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfWalkR2.loc[dfWalkR2['R2']>0]['R2'],dfGroomR2.loc[dfGroomR2['R2']>0]['R2']).pvalue*3))        
        f.write('\n')
        print("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfWalkR2.loc[dfWalkR2['R2']>0]['R2'], dfGroomR2.loc[dfGroomR2['R2']>0]['R2']).pvalue*3))

        f.write('Flail vs Groom')
        f.write(':') 
        f.write("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfFlailR2.loc[dfFlailR2['R2']>0]['R2'],dfGroomR2.loc[dfGroomR2['R2']>0]['R2']).pvalue*3))        
        f.write('\n')
        print("{0:0.10f}".format(scipy.stats.mannwhitneyu(dfFlailR2.loc[dfFlailR2['R2']>0]['R2'],dfGroomR2.loc[dfGroomR2['R2']>0]['R2']).pvalue*3))
# Out:
# 0.0271162320
# 0.0035119959
# 0.0706879563

# %%
sns.boxplot(x='Behavior',y='Coef',data=df_meltedCoef)

plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsAllBehavior.svg')

# %%
result = smf.ols(formula="Coef ~ UAS+GAL4+RegionNames+Behavior+FR", data=df_meltedCoef).fit()
aov_table = anova_lm(result, typ=2)
print(result.rsquared)
aov_table
# Out:
# 0.42841709191940724
#                   sum_sq      df            F         PR(>F)
# UAS           140.422587     5.0    69.872618   2.041776e-57
# GAL4          662.903411     7.0   235.609213  9.885342e-298
# RegionNames   135.491381    40.0     8.427364   1.602865e-46
# Behavior       60.799465     2.0    75.632737   5.177173e-33
# FR            448.203171     1.0  1115.102987  9.579102e-218
# Residual     1739.591183  4328.0          NaN            NaN

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Coef   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     60.07
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):               0.00
# Time:                        11:25:10   Log-Likelihood:                -4194.1
# No. Observations:                4383   AIC:                             8498.
# Df Residuals:                    4328   BIC:                             8849.
# Df Model:                          54
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3783      0.108     12.777      0.000       1.167       1.590
# UAS[T.6m]                -0.5022      0.050    -10.121      0.000      -0.599      -0.405
# UAS[T.6s]                -2.1258      0.130    -16.389      0.000      -2.380      -1.871
# UAS[T.7f]                -0.2822      0.638     -0.442      0.658      -1.534       0.969
# UAS[T.7s]                -1.1169      0.092    -12.141      0.000      -1.297      -0.937
# UAS[T.syt6s]          -7.169e-14   1.48e-14     -4.831      0.000   -1.01e-13   -4.26e-14
# GAL4[T.GMR57C10]          1.2793      0.135      9.457      0.000       1.014       1.545
# GAL4[T.Gad]               0.6064      0.080      7.621      0.000       0.450       0.762
# GAL4[T.Nsyb]             -0.4099      0.078     -5.284      0.000      -0.562      -0.258
# GAL4[T.TDC]               1.0055      0.140      7.188      0.000       0.731       1.280
# GAL4[T.TH]               -0.7277      0.087     -8.395      0.000      -0.898      -0.558
# GAL4[T.Trh]               0.7711      0.146      5.292      0.000       0.485       1.057
# GAL4[T.Vglut]            -0.3444      0.078     -4.388      0.000      -0.498      -0.191
# RegionNames[T.AME]       -0.0900      0.084     -1.069      0.285      -0.255       0.075
# RegionNames[T.AMMC]       0.1071      0.084      1.281      0.200      -0.057       0.271
# RegionNames[T.AOTU]      -0.2123      0.084     -2.539      0.011      -0.376      -0.048
# RegionNames[T.ATL]        0.0677      0.083      0.812      0.417      -0.096       0.231
# RegionNames[T.AVLP]      -0.0896      0.084     -1.071      0.284      -0.253       0.074
# RegionNames[T.BU]        -0.1415      0.083     -1.700      0.089      -0.305       0.022
# RegionNames[T.CAN]        0.3122      0.083      3.742      0.000       0.149       0.476
# RegionNames[T.CRE]       -0.1391      0.083     -1.671      0.095      -0.302       0.024
# RegionNames[T.EB]        -0.1162      0.102     -1.143      0.253      -0.316       0.083
# RegionNames[T.EPA]        0.1541      0.083      1.847      0.065      -0.009       0.318
# RegionNames[T.FB]        -0.0463      0.102     -0.455      0.649      -0.246       0.153
# RegionNames[T.FLA]        0.1850      0.084      2.203      0.028       0.020       0.350
# RegionNames[T.GA]        -0.1474      0.084     -1.756      0.079      -0.312       0.017
#df2=Regionsdf.loc[Regionsdf['GAL4']=='Nsyb']
#df3=df2.loc[df2['UAS']=='6m']
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Groom',data=df3,color='g')
b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='m')
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllGroomg_Walkm.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %% [markdown]
# # Axon vs cytoplasm

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))

df2=Regionsdf

#df2=Regionsdf.loc[Regionsdf['GAL4']=='Nsyb']
df3=df2.loc[df2['UAS']=='syt6s']
#df3=df2.dropna()
df4=df2.loc[df2['UAS']=='6s']

b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='g')
b = sns.boxplot(x='RegionNames',y='R2Walk',data=df4,color='m')
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsAllWalk_sytg_notsyt.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))

df2=Regionsdf

#df2=Regionsdf.loc[Regionsdf['GAL4']=='Nsyb']
df3=df2.loc[df2['UAS']=='syt6s']
#df3=df2.dropna()
df4=df2.loc[df2['UAS']=='6s']

b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df3,color='g')
b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df4,color='m')
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsAllWalk_sytg_notsyt.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
df=Regionsdf.query('UAS=="syt6s"')
df2=df[['R2Walk','RegionNum','RegionNames']]
df2=df2.dropna()

df=df2
file='Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2SytWalk.txt'
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2SytWalk.txt', 'w') as f:
    for j in range(75):
        df2=df.loc[df['RegionNum']==j]
        #f.write(compid)

        f.write(str(np.median(df.loc[df['RegionNames']==list(df2['RegionNames'])[0],'R2Walk'])))        
        f.write('\n')
        print((str(np.median(df2['R2Walk']))))
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\ListR2Files.txt', 'a') as f:
    f.write(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))        
    f.write('\n') 
    print(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))
# Out:
# 0.04972961891213573
# 0.004208819564965327
# 0.19191633035756883
# 0.03852581045065462
# 0.20738454210147683
# 0.05345583821633326
# 0.1224256669635796
# 0.3552281612361884
# 0.3451921268182576
# 0.21137425641677365
# 0.07053561952939957
# 0.2809014318918365
# 0.34740774501826954
# 0.26466258504235507
# 0.03946208539513352
# 0.04371429983832442
# 0.016980707672727635
# 0.05831232500385819
# 0.24188673375744074
# 0.038674462918680486
# 0.12770700109952393
# 0.12852818338875982
# 0.0389878350125456
# 0.19995035867128053
# 0.02670648963854294
# 0.026345733949108552
# 0.03870309236516911
# 0.07635876393638907
# 0.03927495047690821
# 0.1552166576349514
# 0.06915420304249853
# 0.08034304483482158
# 0.17984871697003468
# 0.05525985903998021
# 0.27176673171609667
# 0.3491187654043978
# 0.028286457090410333
# 0.1390984266098373
# 0.3817706420021483
# 0.24589149811116046
# 0.10077373203556628
# 0.0235921648153935
# 0.06294592492468631
# 0.09380880939290992
# 0.03278286463759994
# 0.14725345264344203
# 0.3451515352103156
# 0.46269080690091346
# 0.29782546312320346
# 0.3296887821587957
# 0.35150632213460975
# 0.35471424152763154
# 0.07746216425325825
# 0.14506420670974252
# 0.010195360279960375
# 0.13242207964290043
# 0.2988105303494547
# 0.04918851896101206
# 0.14203835376028573
# 0.08232627629127254
# 0.07013382153600511
# 0.10586621236722804
# 0.039129469077181955
# 0.24774524531716213
# 0.28488416467127076
# 0.45524586511664644
# 0.18620839958991442
# 0.15381263060800165
# 0.35751697981396335
# 0.25039742339804316
# 0.43473118228443264
# 0.4460384547052615
# 0.22093629473226928
# 0.31401597600563014
# 0.09110378122452667
# /media/NAS/Sophie/WalkProject/Figures/Figure1/MedianR2SytWalk.txt

# %%
df=Regionsdf.query('UAS=="6s"')
df2=df[['R2Walk','RegionNum','RegionNames']]
df2=df2.dropna()

df=df2
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2_6sWalk.txt', 'w') as f:
    for j in range(75):
        df2=df.loc[df['RegionNum']==j]
        #f.write(compid)

        f.write(str(np.median(df.loc[df['RegionNames']==list(df2['RegionNames'])[0],'R2Walk'])))        
        f.write('\n')
        
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\ListR2Files.txt', 'a') as f:
    f.write(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))        
    f.write('\n') 
    print(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))
# Out:
# /media/NAS/Sophie/WalkProject/Figures/Figure1/MedianR2SytWalk.txt

# %%
df=Regionsdf.query('UAS=="6s" or UAS=="syt6s"')
result = smf.ols(formula="R2Walk ~ UAS", data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 R2Walk   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     28.12
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           1.34e-07
# Time:                        11:25:18   Log-Likelihood:                 231.47
# No. Observations:                1307   AIC:                            -458.9
# Df Residuals:                    1305   BIC:                            -448.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.2487      0.007     37.495      0.000       0.236       0.262
# UAS[T.syt6s]    -0.0659      0.012     -5.303      0.000      -0.090      -0.042
# ==============================================================================
# Omnibus:                      130.106   Durbin-Watson:                   0.612
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.233
# Skew:                           0.753   Prob(JB):                     5.83e-31
# Kurtosis:                       2.461   Cond. No.                         2.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #
# RegionNames[T.LH]       -0.0694      0.028     -2.448      0.015      -0.125      -0.014
# RegionNames[T.LO]       -0.0467      0.028     -1.646      0.100      -0.102       0.009
# RegionNames[T.LOP]      -0.0750      0.028     -2.644      0.008      -0.131      -0.019
# RegionNames[T.MBCA]     -0.0997      0.028     -3.516      0.000      -0.155      -0.044
# RegionNames[T.MBML]     -0.0484      0.028     -1.706      0.088      -0.104       0.007
# RegionNames[T.MBPED]    -0.0451      0.028     -1.592      0.112      -0.101       0.010
# RegionNames[T.MBVL]     -0.1144      0.028     -4.036      0.000      -0.170      -0.059
# RegionNames[T.ME]       -0.0479      0.029     -1.676      0.094      -0.104       0.008
# RegionNames[T.NO]        0.0190      0.035      0.547      0.584      -0.049       0.087
# RegionNames[T.PB]        0.0623      0.035      1.793      0.073      -0.006       0.130
# RegionNames[T.PLP]       0.0355      0.028      1.252      0.211      -0.020       0.091
# RegionNames[T.PRW]       0.0784      0.035      2.259      0.024       0.010       0.147
# RegionNames[T.PVLP]      0.0069      0.028      0.242      0.809      -0.049       0.062
# RegionNames[T.SAD]       0.0882      0.035      2.541      0.011       0.020       0.156
# RegionNames[T.SCL]      -0.0375      0.028     -1.324      0.186      -0.093       0.018
# RegionNames[T.SIP]      -0.1038      0.028     -3.660      0.000      -0.159      -0.048
# RegionNames[T.SLP]      -0.0406      0.028     -1.431      0.153      -0.096       0.015
# RegionNames[T.SMP]      -0.0444      0.028     -1.564      0.118      -0.100       0.011
# RegionNames[T.SPS]       0.1178      0.028      4.155      0.000       0.062       0.173
# RegionNames[T.VES]       0.0986      0.028      3.479      0.001       0.043       0.154
# eye_painted[T.True]      0.0475      0.007      6.845      0.000       0.034       0.061
# FR                      -0.0059      0.000    -30.552      0.000      -0.006      -0.006
# ==============================================================================
# Omnibus:                       55.403   Durbin-Watson:                   0.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.329
# Skew:                           0.493   Prob(JB):                     7.94e-14
# Kurtosis:                       2.790   Cond. No.                     1.41e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.15e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
aov_table = anova_lm(result, typ=2)
print(result.rsquared)
aov_table
# Out:
# 0.5160337278379907
#                 sum_sq      df           F         PR(>F)
# UAS          15.210110     5.0  199.157933  7.722489e-135
# GAL4         29.640844     7.0  277.222056  6.531720e-102
# RegionNames   6.403145    40.0   10.480176   3.266513e-55
# eye_painted   0.715680     1.0   46.854811   1.147348e-11
# FR           14.257496     1.0  933.423034  5.733934e-157
# Residual     21.048151  1378.0         NaN            NaN

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.loc[Regionsdf['eye_painted']==True]
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    df3=Regionsdf.loc[Regionsdf['eye_painted']==False]
b = sns.boxplot(x='RegionNames',y='CoefWalk',data=df3,color='m')

    
    
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
    b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\CoefRegionsEyeCoveredG_notcoveredMWalk.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.loc[Regionsdf['eye_painted']==True]
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='g')
for i,box in enumerate(b.artists):
    box.set_edgecolor('black')
    box.set_facecolor('green')

    df3=Regionsdf.loc[Regionsdf['eye_painted']==False]
b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='m')

    
    
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
    b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsEyeCoveredG_notcoveredMWalk.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
result = smf.ols(formula="CoefWalk ~ UAS+GAL4+RegionNames+eye_painted", data=Regionsdf).fit()
aov_table = anova_lm(result, typ=2)
print(result.rsquared)
aov_table
# Out:
# 0.18338761987217966
#                  sum_sq      df          F        PR(>F)
# UAS           10.541029     5.0  24.740691  6.301192e-20
# GAL4           3.419214     7.0   5.732276  3.303507e-03
# RegionNames   17.344749    40.0   5.088700  3.839765e-22
# eye_painted    3.920506     1.0  46.008798  1.626581e-11
# Residual     142.900668  1677.0        NaN           NaN

# %%
b = sns.boxplot(x='eye_painted',y='CoefWalk',data=Regionsdf)

# %%
b = sns.boxplot(x='eye_painted',y='R2Walk',data=Regionsdf)

# %%
df3=Regionsdf
df3=df3.loc[df3['UAS']!='7f']
df3=df3.loc[df3['UAS']!='6f']
b = sns.violinplot(x='eye_painted',y='R2Walk',data=df3)
#b = sns.scatterplot(x='eye_painted',y='R2Walk',data=Regionsdf)
plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\AllFliesR2WalkPaintedvsNot_p_is0point2.svg')

# %%
df3=Regionsdf
df3=df3.loc[df3['UAS']!='7f']
df3=df3.loc[df3['UAS']!='6f']
b = sns.boxplot(x='eye_painted',y='R2Walk',data=df3)
#b = sns.scatterplot(x='eye_painted',y='R2Walk',data=Regionsdf)
plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\BoxAllFliesR2WalkPaintedvsNot_p_is0point2.svg')

# %%
df3.loc[df3['eye_painted']==False].groupby('FlyID').mean()
# Out:
#        index     FR  TSlowlimForced  TShighlimForced  TSlowlimFlail  \
# FlyID
# 4       15.0  100.0             NaN              NaN            NaN
# 6       42.5   50.0             NaN              NaN            NaN
# 9       72.5   20.0             NaN              NaN            NaN
# 10     100.0   17.0             NaN              NaN            NaN
# 20     225.0   50.0             NaN              NaN            NaN
# 24     250.0   33.0             NaN              NaN            NaN
#
#        TShighlimFlail  TSlowlimWalk  TShighlimWalk  RegionNum  CoefWalk  \
# FlyID
# 4                 NaN           NaN            NaN       37.0  0.001694
# 6                 NaN           NaN            NaN       37.0  0.020717
# 9                 NaN           NaN            NaN       37.0  0.285128
# 10                NaN           NaN            NaN       37.0  0.672799
# 20                NaN           NaN            NaN       37.0       NaN
# 24                NaN           NaN            NaN       37.0  0.021120
#
#          R2Walk  CoefFlail   R2Flail  CoefGroom   R2Groom        R2
# FlyID
# 4      0.296680        NaN       NaN   0.002437  0.261293  0.261293
# 6      0.113839        NaN       NaN        NaN       NaN       NaN
# 9      0.208650        NaN       NaN        NaN       NaN       NaN
# 10     0.220396   0.375486  0.104424   0.045098  0.002109  0.002109
# 20          NaN        NaN       NaN        NaN       NaN       NaN
# 24     0.104525        NaN       NaN  -0.001509  0.013738  0.013738

# %%
df3.loc[df3['eye_painted']==True].groupby('FlyID').mean()
# Out:
#         index    FR  TSlowlimForced  TShighlimForced  TSlowlimFlail  \
# FlyID
# 11     127.50  20.0             NaN              NaN            NaN
# 13     157.50  42.0             NaN              NaN         2500.0
# 25     263.75   5.0             NaN              NaN            NaN
# 26     287.50   5.0           100.0           3383.0         1000.0
# 27     320.00   NaN             NaN              NaN            NaN
#
#        TShighlimFlail  TSlowlimWalk  TShighlimWalk  RegionNum  CoefWalk  \
# FlyID
# 11                NaN           NaN            NaN       37.0  0.263422
# 13             4996.0           1.0         2000.0       37.0  0.148546
# 25                NaN           NaN            NaN       37.0  0.055832
# 26             4282.0           1.0          950.0       37.0  0.332613
# 27                NaN           1.0         1500.0       37.0  0.280046
#
#          R2Walk  CoefFlail   R2Flail  CoefGroom   R2Groom        R2
# FlyID
# 11     0.238507   0.790319  0.335136        NaN       NaN       NaN
# 13     0.207901   0.033037  0.140254   0.067109  0.004024  0.004024
# 25     0.286687        NaN       NaN        NaN       NaN       NaN
# 26     0.375915   1.043106  0.209752        NaN       NaN       NaN
# 27     0.081646        NaN       NaN        NaN       NaN       NaN

# %%
print("{0:0.10f}".format(scipy.stats.mannwhitneyu(df3.loc[df3['eye_painted']==False].groupby('FlyID').mean()['R2Walk'],df3.loc[df3['eye_painted']==True].groupby('FlyID').mean()['R2Walk']).pvalue))
# Out:
# 0.4636322368

# %%
sns.set_style("whitegrid",{"axes.edgecolor": "0",'grid.color': '0','font.family':'Arial'})
sns.set_context("notebook",font_scale=2)
plt.figure(figsize=(16, 6))
df3=Regionsdf.loc[Regionsdf['eye_painted']==True]
#df3=df2.dropna()

b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='g')


df3=Regionsdf.loc[Regionsdf['eye_painted']==False]
df3=df3.loc[df3['UAS']!='7f']
df3=df3.loc[df3['UAS']!='6f']
b = sns.boxplot(x='RegionNames',y='R2Walk',data=df3,color='m')

    
    
    # iterate over whiskers and median lines
for j in range(6*i,6*(i+1)):
        b.lines[j].set_color('black')
   

plt.xticks(rotation=90)
plt.xticks(fontsize=15)


plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2RegionsEyeCoveredG_notcoveredMWalk.svg')
#plt.savefig('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\R2TurnipsimcontraredAmines.png')
    
plt.show()

# %%
Regionsdf.loc[Regionsdf['eye_painted']==False]['expID'].unique()
# Out:
# array(['216', '100761', '103', '104', 'B34', 'B35', 'B36', 'B37', 'B38',
#        'B39', 'B40', 'B41', 'B42', 'B43', 'B44', '981', '100133',
#        '100160'], dtype=object)

# %%
Regionsdf.loc[Regionsdf['eye_painted']==False]['FR'].unique()
# Out:
# array([ 50., 100.,  20.,   5.,  nan,  33.])

# %%
Regionsdf.loc[Regionsdf['eye_painted']==True]['FR'].unique()
# Out:
# array([50., 10., nan,  5.])

# %%
df3['FR'].unique()
# Out:
# array([50., 20.,  5., nan, 33.])

# %%
df3=Regionsdf.loc[Regionsdf['eye_painted']==False]
df3=df3.loc[df3['UAS']!='7f']
df3=df3.loc[df3['UAS']!='6f']
df3=df3.loc[df3['FR']!=100]

file='Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2_not_eye_paintedWalk.txt'
df=df3
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2_not_eye_paintedWalk.txt', 'w') as f:
    for j in range(75):
        df2=df.loc[df['RegionNum']==j]
        #f.write(compid)

        f.write(str(np.nanmedian(df.loc[df['RegionNames']==list(df2['RegionNames'])[0],'R2Walk'])))        
        f.write('\n')
        print((str(np.nanmedian(df2['R2Walk']))))
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\ListR2Files.txt', 'a') as f:
    f.write(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))        
    f.write('\n') 
    print(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))
# Out:
# 0.10639002123217944
# 0.09500308323691392
# 0.17388112503291786
# 0.15112545579650144
# 0.16446582645624835
# 0.1176380459636377
# 0.1908137450505653
# 0.24188914732740407
# 0.17219790935619111
# 0.23202304301249477
# 0.1974673006689323
# 0.21852175292444692
# 0.22541635056053505
# 0.16520976852816327
# 0.1453325718099684
# 0.15353266516579417
# 0.12387151991838002
# 0.1457344235888749
# 0.21260788870135844
# 0.08212502405913563
# 0.12744422071713923
# 0.18832814975373408
# 0.10169892144250481
# 0.15227628473997218
# 0.1438832940523463
# 0.12633952863227327
# 0.14359249678185232
# 0.15786735707675104
# 0.17551868350387723
# 0.21288792560608072
# 0.2298737873554521
# 0.15411630016847666
# 0.20488521206016186
# 0.0650759525543852
# 0.2487867933174192
# 0.24441993393199307
# 0.16907450476401764
# 0.20679263644782947
# 0.19650547849034322
# 0.22597113473260905
# 0.15326111744101084
# 0.08268985560136177
# 0.05310561922662099
# 0.12100459977889483
# 0.06737218047235838
# 0.15024499047517437
# 0.19929645219345016
# 0.2078288040577425
# 0.14489813162051252
# 0.1954366665096724
# 0.19457076586595012
# 0.14521121534348042
# 0.12888255159012452
# 0.12304669933585155
# 0.10794151057257095
# 0.13052186598533028
# 0.21481160244049924
# 0.03333275031231181
# 0.154730668631326
# 0.056172441219113245
# 0.09690315432209623
# 0.10236782089316765
# 0.1125623142306576
# 0.14503005156616505
# 0.1518798048108499
# 0.19719527746745347
# 0.1542191658049269
# 0.11188865223417455
# 0.16688164429240004
# 0.0527394507542564
# 0.25576019760291346
# 0.20699725057059054
# 0.09069208993986255
# 0.19575711101705262
# 0.12760972256762704
# /media/NAS/Sophie/WalkProject/Figures/Figure1/MedianR2_not_eye_paintedWalk.txt

# %%
df3=Regionsdf.loc[Regionsdf['eye_painted']==True]
df3=df3.loc[df3['UAS']!='7f']
df3=df3.loc[df3['UAS']!='6f']
df=df3
file='Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2_eye_paintedWalk.txt'
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\Figure1\MedianR2_eye_paintedWalk.txt', 'w') as f:
    for j in range(75):
        df2=df.loc[df['RegionNum']==j]
        #f.write(compid)

        f.write(str(np.nanmedian(df.loc[df['RegionNames']==list(df2['RegionNames'])[0],'R2Walk'])))        
        f.write('\n')
        
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\ListR2Files.txt', 'a') as f:
    f.write(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))        
    f.write('\n') 
    print(file.replace('Z:\\GrunwaldKadow_group','/media/NAS').replace('\\','/'))
# Out:
# /media/NAS/Sophie/WalkProject/Figures/Figure1/MedianR2_eye_paintedWalk.txt
