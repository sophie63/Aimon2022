# %% [markdown]
# # Put data together in a pandas dataframe

# %%
import seaborn as sns
from datetime import datetime
from skimage.io import imsave
import openpyxl
import numpy as np
import matplotlib.pyplot as plt
#%plt.style.use("v_paper")
import pandas as pd
from scipy.io import loadmat
# %matplotlib inline
import seaborn as sns
import statsmodels.formula.api as smf
import re
from statsmodels.stats.anova import anova_lm
import os
import os.path
import statsmodels.api as smapi
import sys
import warnings
from sklearn.linear_model import LinearRegression
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import seaborn as sns
import statsmodels as sm
import scipy
from pathlib import Path

# %% [markdown]
# Import data

# %%
datalistPAN=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Pan-NeuronalCalcium\PanAnalysisList.txt',header=None)

datalistSyt=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Pan-NeuronalCalcium\syt6s\SytAnalysisList.txt',header=None)

datalistCha=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Cha\ChaAnalysisList.txt',header=None)

datalistVglut=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Vglut\VglutAnalysisList.txt',header=None)

datalistGad=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Gad\GadAnalysisList.txt',header=None)

datalistTH=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\TH\THAnalysisList.txt',header=None)

datalistTrh=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\Trh\TrhAnalysisList.txt',header=None)

datalistTDC=pd.read_csv('Z:\GrunwaldKadow_group\Sophie\WalkProject\TDC\TDCAnalysisList.txt',header=None)

# %%
datalists=[datalistPAN,datalistSyt,datalistCha,datalistVglut,datalistGad,datalistTH,datalistTrh,datalistTDC]

# %%
AllData=[]
for j in range(0,len(datalists)):
    L=datalists[j][0:datalists[j].shape[0]][0].to_list()
    ID=[AllData.append(i) for i in L]

#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\AllDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\AllDataList.txt', 'w') as f:
    for line in AllData:
        f.write(line)
        f.write('\n')

# %%
PANSytData=[]
for j in range(0,2):
    L=datalists[j][0:datalists[j].shape[0]][0].to_list()
    ID=[PANSytData.append(i) for i in L]

#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\FullPANSytDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\FullPANSytDataList.txt', 'w') as f:
    for line in PANSytData:
        f.write(line)
        f.write('\n')

# %%
GoodICFiles=datalistPAN[0:datalistPAN.shape[0]:5].append(datalistSyt[0:datalistSyt.shape[0]:5]).append(datalistCha[0:datalistCha.shape[0]:5]).append(datalistVglut[0:datalistVglut.shape[0]:5]).append(datalistGad[0:datalistGad.shape[0]:5]).append(datalistTH[0:datalistTH.shape[0]:5]).append(datalistTrh[0:datalistTrh.shape[0]:5]).append(datalistTDC[0:datalistTDC.shape[0]:5])

# %%
FlyID=datalists[0][4:datalistPAN.shape[0]:5]
F=FlyID[0].to_list()
FID=[int(i) for i in F]

for j in range(1,len(datalists)):
    M=max(FID)
    FlyID=datalists[j][4:datalists[j].shape[0]:5]
    F=FlyID[0].to_list()
    ID=[FID.append(int(i)+M) for i in F]

GoodICFiles['FlyID']=FID

# %%
Tfile=datalists[0][1:datalistPAN[0].shape[0]:5]
F=Tfile[0].to_list()
Tf=[i for i in F]

for j in range(1,len(datalists)):
    Tfile=datalists[j][1:datalists[j].shape[0]:5]
    L=Tfile[0].to_list()
    ID=[Tf.append(i) for i in L]

GoodICFiles['Templatefile']=Tf

# %%
TSfile=datalists[0][2:datalistPAN[0].shape[0]:5]
F=TSfile[0].to_list()
TSf=[i for i in F]

for j in range(1,len(datalists)):
    TSfile=datalists[j][2:datalists[j].shape[0]:5]
    L=TSfile[0].to_list()
    ID=[TSf.append(i) for i in L]

GoodICFiles['TSfile']=TSf

# %%
GoodICFiles=GoodICFiles.reset_index()

# %%
for i in range(GoodICFiles.shape[0]):
    HelpString=GoodICFiles.loc[i,0].split('/')    
    if HelpString[len(HelpString)-1].find('GoodIC')!=(-1):    
        GoodICFiles.loc[i,'expID'] = HelpString[len(HelpString)-1].split('GoodIC')[0]
    elif HelpString[len(HelpString)-1].find('goodIC')!=(-1):    
        GoodICFiles.loc[i,'expID'] = HelpString[len(HelpString)-1].split('goodIC')[0]   
    if GoodICFiles.loc[i,'expID']==[]:
        GoodICFiles.loc[i,'expID'] = HelpString[len(HelpString)-1].split('GoodIC')[1]

# %%
GoodICFiles['UAS']=''
UASList=pd.read_csv('UASList.txt',header=None)
for i in range(GoodICFiles.shape[0]):
    GoodICFiles.loc[i,'UAS']=UASList.loc[i,1]

# %%
for i in range(GoodICFiles.shape[0]):
    if GoodICFiles.loc[i,0].find('GMR')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "GMR57C10"
    elif GoodICFiles.loc[i,0].find('Nsyb')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Nsyb"    
    elif GoodICFiles.loc[i,0].find('nsyb')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Nsyb"    
    elif GoodICFiles.loc[i,0].find('Cha')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Cha"    
    elif GoodICFiles.loc[i,0].find('Vglut')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Vglut"  
    elif GoodICFiles.loc[i,0].find('Gad')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Gad"         
    elif GoodICFiles.loc[i,0].find('THDDC')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "TH DDC"    
    elif GoodICFiles.loc[i,0].find('TH')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "TH" 
    elif GoodICFiles.loc[i,0].find('Trh')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Trh"   
    elif GoodICFiles.loc[i,0].find('trh')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "Trh"          
    elif GoodICFiles.loc[i,0].find('TDC')!=(-1):
        GoodICFiles.loc[i,'GAL4'] = "TDC"

# %%
def catch(func, handle=lambda e : e, *args, **kwargs):
    try:
        return func(*args, **kwargs)
    except Exception as e:
        return ' '

# %%
CatPAN=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\\CatPAN.txt",sep='\t',header=None)

# %%
PANSytData=[]
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='Syt')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatPAN[CatPAN[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                PANSytData.append(GoodICFiles.iloc[i]['TSfile'])
                
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='CorrespondancesV5')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatPAN[CatPAN[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                PANSytData.append(GoodICFiles.iloc[i]['TSfile'])
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\PANSytDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\PANSytDataList.txt', 'w') as f:
    for line in PANSytData:
        f.write(line)
        f.write('\n')

VglutData=[]
CatVglut=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\CatVglut.txt",sep='\t',header=None)
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='tABLE CORRESPONDANCE vGLUT')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatVglut[CatVglut[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':    
                VglutData.append(GoodICFiles.iloc[i]['TSfile'])
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\VglutshortDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\VglutshortDataList.txt', 'w') as f:
    for line in VglutData:
        f.write(line)
        f.write('\n')

GadData=[]
CatGad=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\CatGad.txt",sep='\t',header=None)
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='ANNOTATION GAD')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatGad[CatGad[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                GadData.append(GoodICFiles.iloc[i]['TSfile'])
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\GadshortDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\GadshortDataList.txt', 'w') as f:
    for line in VglutData:
        f.write(line)
        f.write('\n')

ChaData=[]
CatCha=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\CatCha.txt",sep='\t',header=None)
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='Annotation CHA')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatCha[CatCha[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                ChaData.append(GoodICFiles.iloc[i]['TSfile'])                    
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\ChashortDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\ChashortDataList.txt', 'w') as f:
    for line in ChaData:
        f.write(line)
        f.write('\n')

THTrhData=[]
CatTHTrh=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\CatTHTrh.txt",sep='\t',header=None)
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='TableCorrespondanceTH_trh')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] = ','.join([catch(lambda:CatTHTrh[CatTHTrh[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                THTrhData.append(GoodICFiles.iloc[i]['TSfile'])       
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\THTrhshortDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\THTrhshortDataList.txt', 'w') as f:
    for line in THTrhData:
        f.write(line)
        f.write('\n')            

TDCData=[]
CatTDC=pd.read_csv("Z:\GrunwaldKadow_group\Sophie\WalkProject\CatTDC.txt",sep='\t',header=None)
df = pd.read_excel("Z:\GrunwaldKadow_group\Sophie\WalkProject\Figures\BigDataTable.xlsx",sheet_name='CorrespondanceTDC')
for i in range(GoodICFiles.shape[0]):
    for j in range(df.columns.shape[0]):
        if GoodICFiles.iloc[i]['expID'] == str(df.columns[j]):
            GoodICFiles.loc[GoodICFiles.index == i, ['Correspondance']] =','.join([catch(lambda:CatTDC[CatTDC[1]==k].iloc[0,0]) if (type(k)==int or type(k)==float) else k for k in df[df.columns[j]].to_list()])
            if GoodICFiles.iloc[i]['Correspondance'] != ' ':
                TDCData.append(GoodICFiles.iloc[i]['TSfile'])                    
#with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\TDCshortDataList.txt', 'w') as f:
with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\TDCshortDataList.txt', 'w') as f:
    for line in TDCData:
        f.write(line)
        f.write('\n')

# %%
TSData=[]

for i in range(GoodICFiles.shape[0]):
    if GoodICFiles.iloc[i]['Correspondance'] != ' ':
        TSData.append(GoodICFiles.iloc[i]['TSfile'])        

with open('Z:\GrunwaldKadow_group\Sophie\WalkProject\AllTSDataList.txt', 'w') as f:
    for line in TSData:
        f.write(line)
        f.write('\n')

# %%
GoodICFiles=pd.read_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\GoodICsdf.pkl")

# %%
GoodICFiles['RegionFile']=''

for dirpath, dirnames, filenames in os.walk("Z:\GrunwaldKadow_group\Sophie\WalkProject", topdown = False):
    for filename in [f for f in filenames if f.endswith("TS12Regions.mat")]:
        ID=os.path.join(dirpath, filename).split('\\')
        IDh0=ID[len(ID)-1]
        IDh=IDh0.split('Tr')[0]
        IDh1=IDh.split('reg')[0]
        IDh2=IDh1.split('ss')[0]
        IDh3=IDh2.split('Data')
        IDh4=IDh3[len(IDh3)-1].split('TS_LR')[0]  
        IDh5=IDh4.split('_')[0]
        IDh6=IDh5.split('GoodIC')[0]   
        print(filename)
        print(IDh6) 
        
        for i in range(GoodICFiles.shape[0]):
            
            ID2=IDh[0:(len(GoodICFiles.iloc[i]['expID']))]
            IDg=GoodICFiles.iloc[i]['TSfile'].split('/')
            if GoodICFiles.iloc[i]['expID'] == IDh6:                            
                GoodICFiles.loc[GoodICFiles.index == i,['12RegionFile']] =os.path.join(dirpath, filename)
                print(IDh6)
# Out:
# 100160
# 100160
# 100160
# 100160
# B1072
# B1072
# B1073
# B1073
# B1074
# B1074
# B1075
# B1075
# B1076
# B1076
# B1080
# B1080
# B1089
# B1089
# B1090
# B1090
# B757
# B757
# B758
# B758
# B1133
# B1133
# B1134
# B1134
# B116
# B116
# B117
# B117
# B118
# B118
# B129
# B129
# B130
# B130
# B131
# B131
# B132
# B132
# B133
# B133
# B134
# B134
# B140
# B140
# B153
# B153
# 100761
# 100761
# 100762
# 100762
# 100765series
# 100784series
# B991
# B991
# B992
# B992
# B993
# B993
# B995
# B995
# B996
# B996
# B998
# B998
# B999
# B999
# B1000
# B1000
# B1002
# B1002
# GSB3
# B1037
# B1037
# B1043
# B1043
# B291
# B291
# B322
# B322
# B323
# B323
# B406
# GSB4
# GSB5
# GSB6
# GSB7
# GSB2
# 100450
# 100450
# 103
# 103
# 104
# 104
# 105
# 105
# B180
# B180
# B182
# B182
# B183
# B183
# B184
# B184
# B190
# B190
# B192
# B192
# B193
# B193
# B194
# B194
# B195
# B195
# B196
# B196
# B197
# B197
# B34
# B34
# B35
# B35
# B36
# B36
# B37
# B37
# B38
# B38
# B39
# B39
# B40
# B40
# B41
# ...

# %%
GoodICFiles.to_pickle("GoodICsdf.pkl")
GoodICFiles.to_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\GoodICsdf.pkl")

# %%
GoodICFiles['WalkRegressor']=''
GoodICFiles['GroomRegressor']=''
GoodICFiles['FlailRegressor']=''
GoodICFiles['TurnRegressor']=''
GoodICFiles['ForcedWalkRegressor']=''
GoodICFiles['ForcedTurnRegressor']=''

for dirpath, dirnames, filenames in os.walk("Z:\GrunwaldKadow_group\Sophie\WalkProject", topdown = False):
    for filename in [f for f in filenames if f.endswith("kd.mat")]:
        ID=os.path.join(dirpath, filename).split('\\')
        for i in range(GoodICFiles.shape[0]):
            IDh=ID[len(ID)-1]
            ID2=IDh[0:(len(GoodICFiles.iloc[i]['expID']))]
            IDg=GoodICFiles.iloc[i]['TSfile'].split('/')
            #print(ID2)  
            #print(GoodICFiles.iloc[i]['expID'])
            if GoodICFiles.iloc[i]['expID'] == ID2 and ID[len(ID)-2] == IDg[len(IDg)-2]:             
                if (('Walk' in filename) or ('walk' in filename) or ('Rbinkd' in filename)) and not ('Ron' in filename):                
                    GoodICFiles.loc[GoodICFiles.index == i,['WalkRegressor']] =os.path.join(dirpath, filename)
                    print(filename)
                elif ('Forced' in filename and not('ForcedLR'in filename )):                
                    GoodICFiles.loc[GoodICFiles.index == i, ['ForcedWalkRegressor']] =os.path.join(dirpath, filename)                 
                    #print(filename)
                if ('groom' in filename) or ('Groom' in filename):                
                    GoodICFiles.loc[GoodICFiles.index == i, ['GroomRegressor']] =os.path.join(dirpath, filename) 
                    print(filename)
                    #print(GoodICFiles.iloc[i]['GAL4'])                
                if ('Flail' in filename) or ('flail' in filename):                
                    GoodICFiles.loc[GoodICFiles.index == i, ['FlailRegressor']] =os.path.join(dirpath, filename)   

                if ('Turn' in filename) or ('turn' in filename) or ('Dir' in filename):                
                    GoodICFiles.loc[GoodICFiles.index == i, ['TurnRegressor']] =os.path.join(dirpath, filename) 
                    #print(GoodICFiles.iloc[i]['TurnRegressor'])
                elif ('ForcedLR' in filename):                
                    GoodICFiles.loc[GoodICFiles.index == i, ['ForcedTurnRegressor']] =os.path.join(dirpath, filename)                 
                     

                #else:
                    #print(filename)
# Out:
# 100160WalkRbinkd.mat
# B1073WalkRbinkd.mat
# B1075Walkbin1to1060kd.mat
# B1080Walk1-2600kd.mat
# B1090WalkRbinkd.mat
# B116WalkRbinkd.mat
# B117WalkRbinkd.mat
# B118Walkbinkd.mat
# B126WalkRbinkd.mat
# B130WalkRbinkd.mat
# B132WalkRbinkd.mat
# B134WalkRbinkd.mat
# B140Walkbinkd.mat
# B153WalkRbinkd.mat
# 100761RbinGroomkd.mat
# 100761Rbinkd.mat
# 100761RbinWalkkd.mat
# 100762WalkRbinkd.mat
# B993WalkRbinkd.mat
# B996WalkRbinkd.mat
# 100133Groomkd.mat
# 100133WalkRbinkd.mat
# B1047Walk1_1500kd.mat
# B1037Walk1_950kd.mat
# 100148Groomkd.mat
# 100148RbinWalkkd.mat
# 100234WalkRbinkd.mat
# 100609Rbinkd.mat
# 100106Rbinkd.mat
# 103Walkbinkd.mat
# 104Walkbinkd.mat
# B180WalkRkd.mat
# B182Walkbinkd.mat
# B183RbinWalkkd.mat
# B192Groomkd.mat
# B196Walkbinkd.mat
# B193Walkbinkd.mat
# B195Walkkd.mat
# B192_1_2000Walkd.mat
# B194Walkbinkd.mat
# B34Rbinkd.mat
# B38Rbinkd.mat
# B37Rbinkd.mat
# B36Rbinkd.mat
# B35Rbinkd.mat
# B39Rbinkd.mat
# B40Rbinkd.mat
# B41Rbinkd.mat
# B42RbinWalkkd.mat
# ...

# %% [markdown]
# ## Manually fill missing parameters

# %%
GoodICFiles.loc[GoodICFiles['expID'] == 'B754', ['FR']]=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B991', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B992', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B993', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B996', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B998', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B999', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == 'B1000', ['GAL4']]='Nsyb'
GoodICFiles.loc[GoodICFiles['expID'] == '100762', ['GAL4']]='GMR57C10'

# %%
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TSlowlimForced']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TShighlimForced']=3383
GoodICFiles.loc[GoodICFiles['expID'] == 'B350','TSlowlimForced']=3650
GoodICFiles.loc[GoodICFiles['expID'] == 'B350','TShighlimForced']=3900
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TSlowlimForced']=600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TShighlimForced']=1500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1260','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1260','TShighlimForced']=349
GoodICFiles.loc[GoodICFiles['expID'] == '158','TSlowlimFlail']=1
GoodICFiles.loc[GoodICFiles['expID'] == '158','TShighlimFlail']=600

# %%
GoodICFiles.loc[GoodICFiles['expID'] == '100142','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == '100142','TShighlimWalk']=12372
GoodICFiles.loc[GoodICFiles['expID'] == '100455','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == '100455','TShighlimWalk']=1500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TShighlimWalk']=950
GoodICFiles.loc[GoodICFiles['expID'] == '100455','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == '100455','TShighlimWalk']=5000
GoodICFiles.loc[GoodICFiles['expID'] == '100621','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == '100621','TShighlimWalk']=5990
GoodICFiles.loc[GoodICFiles['expID'] == 'B1126','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1126','TShighlimWalk']=1800
GoodICFiles.loc[GoodICFiles['expID'] == 'B1128','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1128','TShighlimWalk']=1500
GoodICFiles.loc[GoodICFiles['expID'] == '100405','TSlowlimWalk']=1000
GoodICFiles.loc[GoodICFiles['expID'] == '100405','TShighlimWalk']=2000
GoodICFiles.loc[GoodICFiles.index==126,'TSlowlimWalk']=2
GoodICFiles.loc[GoodICFiles.index==126,'TShighlimWalk']=4999
GoodICFiles.loc[GoodICFiles['expID'] == 'B1125','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1126','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1128','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1129','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1070','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == '370','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == '371','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == '372','FR']=2
GoodICFiles.loc[GoodICFiles['expID'] == '369','FR']=4
#GoodICFiles.loc[GoodICFiles['expID'] == '46','TSlowlimWalk']=143
#GoodICFiles.loc[GoodICFiles['expID'] == '46','TShighlimWalk']=5999
GoodICFiles.loc[GoodICFiles['expID'] == 'B219','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B219','TShighlimWalk']=2000
GoodICFiles.loc[GoodICFiles['expID'] == 'B350','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B350','TShighlimWalk']=3000
GoodICFiles.loc[GoodICFiles['expID'] == 'B266','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B266','TShighlimWalk']=2600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1054','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1054','TShighlimWalk']=2130
GoodICFiles.loc[GoodICFiles['expID'] == 'B1069','TSlowlimWalk']=70
GoodICFiles.loc[GoodICFiles['expID'] == 'B1069','TShighlimWalk']=103
GoodICFiles.loc[GoodICFiles['expID'] == 'B1065','TSlowlimWalk']=350
GoodICFiles.loc[GoodICFiles['expID'] == 'B1065','TShighlimWalk']=2071
GoodICFiles.loc[GoodICFiles['expID'] == 'B1066','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1066','TShighlimWalk']=4600
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TShighlimWalk']=1700
GoodICFiles.loc[GoodICFiles['expID'] == 'B74','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B74','TShighlimWalk']=3000
GoodICFiles.loc[GoodICFiles['expID'] == 'B192','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B192','TShighlimWalk']=2000
GoodICFiles.loc[GoodICFiles['expID'] == 'B152','TSlowlimWalk']=700
GoodICFiles.loc[GoodICFiles['expID'] == 'B152','TShighlimWalk']=700+4299+1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1047','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1047','TShighlimWalk']=1500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1253','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1253','TShighlimWalk']=650
GoodICFiles.loc[GoodICFiles['expID'] == 'B1269','TSlowlimWalk']=70
GoodICFiles.loc[GoodICFiles['expID'] == 'B1269','TShighlimWalk']=103
GoodICFiles.loc[GoodICFiles['expID'] == 'B1003','TSlowlimForced']=2
GoodICFiles.loc[GoodICFiles['expID'] == 'B1003','TShighlimForced']=2405
GoodICFiles.loc[GoodICFiles['expID'] == 'B1043','TSlowlimForced']=2
GoodICFiles.loc[GoodICFiles['expID'] == 'B1043','TShighlimForced']=1077
GoodICFiles.loc[GoodICFiles['expID'] == 'B1061','TSlowlimForced']=500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1061','TShighlimForced']=1032
GoodICFiles.loc[GoodICFiles['expID'] == 'B1251','TSlowlimForced']=650
GoodICFiles.loc[GoodICFiles['expID'] == 'B1251','TShighlimForced']=1950
GoodICFiles.loc[GoodICFiles['expID'] == 'B1252','TSlowlimWalk']=400
GoodICFiles.loc[GoodICFiles['expID'] == '100597','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == '100597','TShighlimWalk']=9500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1252','TShighlimWalk']=1670
GoodICFiles.loc[GoodICFiles['expID'] == 'B696','TSlowlimWalk']=3500
GoodICFiles.loc[GoodICFiles['expID'] == 'B696','TShighlimWalk']=4576
GoodICFiles.loc[GoodICFiles['expID'] == 'B1276','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1276','TShighlimWalk']=500
GoodICFiles.loc[GoodICFiles['expID'] == 'B700','TSlowlimWalk']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B700','TShighlimWalk']=3100
GoodICFiles.loc[GoodICFiles['expID'] == 'B675','TSlowlimForced']=3001
GoodICFiles.loc[GoodICFiles['expID'] == 'B675','TShighlimForced']=5998
GoodICFiles.loc[GoodICFiles['expID'] == 'B676','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B676','TShighlimForced']=2000
GoodICFiles.loc[GoodICFiles['expID'] == 'B765','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B767','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B766','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B768','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TShighlimForced']=1700
GoodICFiles.loc[GoodICFiles['expID'] == 'B902','TSlowlimForced']=600
GoodICFiles.loc[GoodICFiles['expID'] == 'B902','TShighlimForced']=1500
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B1269','TSlowlimForced']=240
GoodICFiles.loc[GoodICFiles['expID'] == 'B1269','TShighlimForced']=536
GoodICFiles.loc[GoodICFiles['expID'] == 'B1269','FR']=2
GoodICFiles.loc[GoodICFiles['expID'] == 'B1273','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1273','TShighlimForced']=350
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TSlowlimForced']=600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TShighlimForced']=1500
GoodICFiles.loc[GoodICFiles['expID'] == 'B1262','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1262','TShighlimForced']=600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1262','TSlowlimFlail']=2000
GoodICFiles.loc[GoodICFiles['expID'] == 'B1262','TShighlimFlail']=2158
GoodICFiles.loc[GoodICFiles['expID'] == 'B1273','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','TSlowlimForced']=1474
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','TShighlimForced']=2800
GoodICFiles.loc[GoodICFiles['expID'] == 'B361','TSlowlimForced']=290
GoodICFiles.loc[GoodICFiles['expID'] == 'B361','TShighlimForced']=468
GoodICFiles.loc[GoodICFiles['expID'] == 'B362','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B362','TShighlimForced']=950
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TSlowlimForced']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','TShighlimForced']=1700
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B379','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B1075','TSlowlimFlail']=1120
GoodICFiles.loc[GoodICFiles['expID'] == 'B1075','TShighlimFlail']=2011
GoodICFiles.loc[GoodICFiles['expID'] == 'B1075','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1134','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1134','TSlowlimFlail']=1186
GoodICFiles.loc[GoodICFiles['expID'] == 'B1134','TShighlimFlail']=1318
GoodICFiles.loc[GoodICFiles['expID'] == 'B177','TSlowlimFlail']=4200
GoodICFiles.loc[GoodICFiles['expID'] == 'B177','TShighlimFlail']=4600
GoodICFiles.loc[GoodICFiles['expID'] == 'B177','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B169','TSlowlimFlail']=1000
GoodICFiles.loc[GoodICFiles['expID'] == 'B169','TShighlimFlail']=3000
GoodICFiles.loc[GoodICFiles['expID'] == 'B1129','TSlowlimFlail']=280
GoodICFiles.loc[GoodICFiles['expID'] == 'B1129','TShighlimFlail']=450
GoodICFiles.loc[GoodICFiles['expID'] == 'B169','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1253','TSlowlimFlail']=1065
GoodICFiles.loc[GoodICFiles['expID'] == 'B1253','TShighlimFlail']=2660
GoodICFiles.loc[GoodICFiles['expID'] == 'B1253','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1226','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B305','TSlowlimFlail']=3000
GoodICFiles.loc[GoodICFiles['expID'] == 'B305','TShighlimFlail']=4995
GoodICFiles.loc[GoodICFiles['expID'] == 'B305','TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B305','TShighlimWalk']=2500
GoodICFiles.loc[GoodICFiles['expID'] == 'B305','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B266','TSlowlimFlail']=2840
GoodICFiles.loc[GoodICFiles['expID'] == 'B266','TShighlimFlail']=4997
GoodICFiles.loc[GoodICFiles['expID'] == 'B266','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TSlowlimFlail']=1600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','TShighlimFlail']=2600
GoodICFiles.loc[GoodICFiles['expID'] == 'B1277','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1279','TSlowlimFlail']=1
GoodICFiles.loc[GoodICFiles['expID'] == 'B1279','TShighlimFlail']=800
GoodICFiles.loc[GoodICFiles['expID'] == 'B1279','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','TSlowlimFlail']=2883
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','TShighlimFlail']=2998
GoodICFiles.loc[GoodICFiles['expID'] == 'B1275','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1066','TSlowlimFlail']=4991
GoodICFiles.loc[GoodICFiles['expID'] == 'B1066','TShighlimFlail']=4991+1006
GoodICFiles.loc[GoodICFiles['expID'] == 'B1066','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == '193','TSlowlimFlail']=800
GoodICFiles.loc[GoodICFiles['expID'] == '193','TShighlimFlail']=2300
GoodICFiles.loc[GoodICFiles['expID'] == 'B192','TSlowlimFlail']=2500
GoodICFiles.loc[GoodICFiles['expID'] == 'B192','TShighlimFlail']=4996
GoodICFiles.loc[GoodICFiles['expID'] == '100145','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100145','TSlowlimFlail']=3000
GoodICFiles.loc[GoodICFiles['expID'] == '100145','TShighlimFlail']=4000
GoodICFiles.loc[GoodICFiles['expID'] == 'B373','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B373','TSlowlimFlail']=1000
GoodICFiles.loc[GoodICFiles['expID'] == 'B373','TShighlimFlail']=2400
GoodICFiles.loc[GoodICFiles['expID'] == '29','FR']=1/0.03
GoodICFiles.loc[GoodICFiles['expID'] == '29','TSlowlimFlail']=1
GoodICFiles.loc[GoodICFiles['expID'] == '29','TShighlimFlail']=350
GoodICFiles.loc[GoodICFiles['expID'] == '167','FR']=15
GoodICFiles.loc[GoodICFiles['expID'] == '167','TSlowlimFlail']=1
GoodICFiles.loc[GoodICFiles['expID'] == '167','TShighlimFlail']=350
GoodICFiles.loc[GoodICFiles['expID'] == '47','FR']=1/0.03
GoodICFiles.loc[GoodICFiles['expID'] == '47','TShighlimFlail']=3910
GoodICFiles.loc[GoodICFiles['expID'] == '47','TShighlimFlail']=6000
GoodICFiles.loc[GoodICFiles['expID'] == '158','FR']=1/0.03
GoodICFiles.loc[GoodICFiles['expID'] == 'B1062','TSlowlimFlail']=1000
GoodICFiles.loc[GoodICFiles['expID'] == 'B1062','TShighlimFlail']=2158
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TSlowlimFlail']=1000
GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','TShighlimFlail']=4282
GoodICFiles.loc[GoodICFiles['expID'] == 'KC00060','TSlowlimFlail']=1050
GoodICFiles.loc[GoodICFiles['expID'] == 'KC00060','TShighlimFlail']=5997
GoodICFiles.loc[GoodICFiles['expID'] == 'B192','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B193','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B194','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B195','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B197','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B180','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B181','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B182','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B183','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B184','FR']=10

GoodICFiles.loc[GoodICFiles['expID'] == 'B34','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B35','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B36','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B37','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B38','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B361','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B362','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B378','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B39','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B40','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B41','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B43','FR']=50

GoodICFiles.loc[GoodICFiles['expID'] == '247','FR']=1/0.066
GoodICFiles.loc[GoodICFiles['expID'] == '249','FR']=1/0.066
GoodICFiles.loc[GoodICFiles['expID'] == '251','FR']=1/0.066

GoodICFiles.loc[GoodICFiles['expID'] == '216','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '103','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '104','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '105','FR']=50

GoodICFiles.loc[GoodICFiles['expID'] == '100761','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == '100762','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == '100763','FR']=100

GoodICFiles.loc[GoodICFiles['expID'] == '100609','FR']=98
GoodICFiles.loc[GoodICFiles['expID'] == 'GSB7','FR']=98
GoodICFiles.loc[GoodICFiles['expID'] == 'GSB5','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100234','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'GSB3','FR']=33
GoodICFiles.loc[GoodICFiles['expID'] == '100133','FR']=33
GoodICFiles.loc[GoodICFiles['expID'] == 'GSB2','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100106','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'GSB1','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '981','FR']=50

GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B993','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == '358','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == '359','FR']=3.33
GoodICFiles.loc[GoodICFiles['expID'] == '360','FR']=3.33

GoodICFiles.loc[GoodICFiles['expID'] == '372','FR']=2

GoodICFiles.loc[GoodICFiles['expID'] == 'B322','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B323','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B190','FR']=10

GoodICFiles.loc[GoodICFiles['expID'] == 'B73','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B74','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B75','FR']=20

GoodICFiles.loc[GoodICFiles['expID'] == 'B66','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B67','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B68','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B70','FR']=20

GoodICFiles.loc[GoodICFiles['expID'] == 'B99','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B100','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B167','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B168','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B169','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B170','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B171','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B172','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B173','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B174','FR']=20

GoodICFiles.loc[GoodICFiles['expID'] == 'B175','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B176','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B177','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B178','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B116','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == 'B117','FR']=2
GoodICFiles.loc[GoodICFiles['expID'] == 'B118','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B126','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B127','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B128','FR']=77
GoodICFiles.loc[GoodICFiles['expID'] == 'B129','FR']=77

GoodICFiles.loc[GoodICFiles['expID'] == 'B140','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B141','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B153','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B154','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B130','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B131','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B132','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B133','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B134','FR']=100

GoodICFiles.loc[GoodICFiles['expID'] == 'B192','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B193','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B194','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B195','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B196','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B197','eye_painted']=True

GoodICFiles.loc[GoodICFiles['expID'] == 'B991','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B992','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B993','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B996','eye_painted']=True


GoodICFiles.loc[GoodICFiles['expID'] == 'B1037','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B1039','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B1047','eye_painted']=True


GoodICFiles.loc[GoodICFiles['expID'] == 'B180','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B181','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B182','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B183','eye_painted']=True
GoodICFiles.loc[GoodICFiles['expID'] == 'B184','eye_painted']=True

GoodICFiles.loc[GoodICFiles['expID'] == 'B34','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B35','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B36','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B37','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B38','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B39','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B40','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B41','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B42','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B43','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == 'B44','eye_painted']=False

GoodICFiles.loc[GoodICFiles['expID'] == '103','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == '104','eye_painted']=False

GoodICFiles.loc[GoodICFiles['expID'] == '216','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == '100160','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == '981','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == '100133','eye_painted']=False
GoodICFiles.loc[GoodICFiles['expID'] == '100761','eye_painted']=False

GoodICFiles.loc[GoodICFiles['expID'] == '100761','GAL4']='GMR57C10'
GoodICFiles.loc[GoodICFiles['expID'] == 'B1276','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == '100455','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100597','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100621','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B370','FR']=10

GoodICFiles.loc[GoodICFiles['expID'] == '46','FR']=1/0.03
GoodICFiles.loc[GoodICFiles['expID'] == 'B1054','FR']=5
#GoodICFiles.loc[GoodICFiles['expID'] == '194','FR']=
GoodICFiles.loc[GoodICFiles['expID'] == 'B97','FR']=10
GoodICFiles.loc[GoodICFiles['expID'] == 'B122','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B123','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B124','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B152','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B155','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B158','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == 'B1065','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == '194','FR']=1/0.066

GoodICFiles.loc[GoodICFiles['expID'] == 'B219','FR']=20

GoodICFiles.loc[GoodICFiles['expID'] == 'B698','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B700','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1252','FR']=5

GoodICFiles.loc[GoodICFiles['expID'] == 'B42','FR']=5
#GoodICFiles.loc[GoodICFiles['expID'] == 'B196','FR']=
GoodICFiles.loc[GoodICFiles['expID'] == 'B1047','FR']=20
GoodICFiles.loc[GoodICFiles['expID'] == '100160','FR']=100
GoodICFiles.loc[GoodICFiles['expID'] == 'B1073','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1080','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == 'B1090','FR']=5
GoodICFiles.loc[GoodICFiles['expID'] == '107','FR']=50
GoodICFiles.loc[GoodICFiles['expID'] == '100142','FR']=50

GoodICFiles.loc[GoodICFiles.index==126,'TSlowlimWalk']=2
GoodICFiles.loc[GoodICFiles.index==126,'TShighlimWalk']=4999

# %%
GoodICFiles.loc[GoodICFiles['expID']=='216']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100762']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='103']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='100106']['TurnChecked']='WasInverted_NowCorrectedforLisBall'
GoodICFiles.loc[GoodICFiles['expID']=='B34']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='B35']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B36']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='B37']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='100148']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='100234']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100609']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='981']['TurnChecked']='FluoWasFlipped_butprobablyvideotoo_sinceunclear_remove'
GoodICFiles.loc[GoodICFiles['expID']=='100133']['TurnChecked']='WasInverted_NowCorrectedforLisBall'
GoodICFiles.loc[GoodICFiles['expID']=='B44']['TurnChecked']='BehaviorUnclear'
GoodICFiles.loc[GoodICFiles['expID']=='B182']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B183']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B192']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles['expID']=='B194']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B195']['TurnChecked']='TrackingNotGood'

GoodICFiles.loc[GoodICFiles['expID']=='107']['TurnChecked']='FluoWasFlipped'
GoodICFiles.loc[GoodICFiles['expID']=='100142']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100405']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100411']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100455']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100597']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='100621']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B370']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B373']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='B365']['TurnChecked']='LisLball'
GoodICFiles.loc[GoodICFiles['expID']=='40']['TurnChecked']='ActuallyStraight'

GoodICFiles.loc[GoodICFiles['expID']=='194']['TurnChecked']='TrackingNotGood'
GoodICFiles.loc[GoodICFiles.index==0,'TSlowlimWalk']=0
GoodICFiles.loc[GoodICFiles.index==0,'TShighlimWalk']=4999
GoodICFiles.loc[GoodICFiles.index==126,'TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles.index==130,'TSlowlimWalk']=1
GoodICFiles.loc[GoodICFiles.index==130,'TShighlimWalk']=3000
GoodICFiles.loc[GoodICFiles.index==33,'FR']=50
GoodICFiles.loc[GoodICFiles.index==41,'FR']=100

# %%
GoodICFiles.loc[GoodICFiles['expID']=='216','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='244','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='254','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100761','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='100762','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='103','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='104','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='105','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100106','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100450','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B34','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B35','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B36','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B37','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B38','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B39','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B40','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B41','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B42','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B43','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B44','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B180','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B182','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B183','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B184','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B190','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B192','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B193','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B194','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B195','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B196','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B197','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B640','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B642','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B643','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B656','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B658','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='100148','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='100234','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100498','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100609','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='981','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B291','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B322','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B323','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B406_321_','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100133','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B991','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B992','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B993','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B996','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B998','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1037','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1039','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1042','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1043','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1044','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1045','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1046','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1047','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1048','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1049','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1050','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1000','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B999','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B675','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B676','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B677','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B679','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B902','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B903','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B905','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1241','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1242','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1245','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1246','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1003','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1004','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B959','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B960','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B961','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='221','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='247','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='249','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='251','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1125','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1070','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1126','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B9','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='368','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1128','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='359','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='360','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='370','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='371','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='372','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B1072','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1073','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1075','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1076','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1080','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1089','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1090','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B757','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B758','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B754','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100160','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='773','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B1133','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1134','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1141','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1151','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1145','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B153','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B154','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B141','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B140','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B134','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B116','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B117','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B118','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B126','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B127','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B129','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B130','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B131','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B132','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B133','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B996','FR']=50
GoodICFiles.loc[GoodICFiles['expID']=='B156','FR']=50
GoodICFiles.loc[GoodICFiles['expID']=='100405','FR']=100
GoodICFiles.loc[GoodICFiles['expID']=='100411','FR']=100
GoodICFiles.loc[GoodICFiles['expID']=='B696','FR']=5
GoodICFiles.loc[GoodICFiles['expID']=='B350','FR']=5
GoodICFiles.loc[GoodICFiles['expID']=='273','FR']=15
GoodICFiles.loc[GoodICFiles['expID']=='B1279','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1278','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1277','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1276','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1275','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1273','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1066','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1065','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B368','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B355','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B353','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B352','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B351','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B350','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B346','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B345','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B344','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B343','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B340','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B158','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B156','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B155','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B152','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B124','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B123','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B122','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B97','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='273','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='272','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='195','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='194','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='TUM45','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='TUM42','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='46','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1055','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1054','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B768','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B767','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B766','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B765','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B764','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B377','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B375','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B374','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B373','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B379','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B378','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B372','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B370','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B369','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B365','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B362','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B361','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='100621','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100597','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100457','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100456','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='100145','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='100411','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='100405','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='100142','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='107','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B1271','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1270','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1269','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1268','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1267','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1266','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1265','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1264','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1261','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1260','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1254','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B1253','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1252','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B1251','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B1248','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B703','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B701','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B700','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B698','WalkSubstrate']='Straight'
GoodICFiles.loc[GoodICFiles['expID']=='B697','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B696','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B336','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B308','WalkSubstrate']='RotRod'
GoodICFiles.loc[GoodICFiles['expID']=='B305','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B304','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B266','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B218','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B219','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B217','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B177','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B176','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B175','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B169','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B167','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B100','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B99','WalkSubstrate']='Styr'
GoodICFiles.loc[GoodICFiles['expID']=='B75','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B74','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B70','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B68','WalkSubstrate']='AirBall'
GoodICFiles.loc[GoodICFiles['expID']=='B66','WalkSubstrate']='Styr'

# %%
for i in range(GoodICFiles.shape[0]):
    if (GoodICFiles.loc[GoodICFiles.index == i,'Correspondance'].isnull()).all():
        GoodICFiles.loc[GoodICFiles.index == i,'Correspondance']=''

# %%
GoodICFiles.to_pickle("GoodICsdf.pkl")
GoodICFiles.to_pickle("Z:\GrunwaldKadow_group\Sophie\WalkProject\GoodICsdf.pkl")
