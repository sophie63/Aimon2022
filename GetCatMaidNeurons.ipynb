# %%
import pymaid

# %%
rm = pymaid.CatmaidInstance('https://fafb.catmaid.virtualflybrain.org/',api_token=None)
# Out:
# INFO  : Global CATMAID instance set. Caching is ON. (pymaid)

# %%
pymaid.find_neurons()
# Out:
# Your search parameters will retrieve ALL neurons in the dataset. Proceed? [Y/N]  Y
# INFO  : Get all neurons with >= 1 nodes (pymaid)
# Make nrn:   0%|          | 0/4210 [00:00<?, ?it/s]
# INFO  : Found 4210 neurons matching the search parameters (pymaid)
# <class 'pymaid.core.CatmaidNeuronList'> containing 4210 neurons (est. 0.0B)
#                type                                     name skeleton_id  \
# 0     CatmaidNeuron  PD5g1_L#3 8880132 ECM Tarly family left     8880131
# 1     CatmaidNeuron                           KCaBx 12719 CF    10190852
# ...             ...                                      ...         ...
# 4208  CatmaidNeuron       LHAD1c1#1 3080184 Dust World JJ PS     3080183
# 4209  CatmaidNeuron                               KC 7503 CF     8421369
#
#      n_nodes n_connectors n_branches n_leafs cable_length soma        units
# 0         NA           NA         NA      NA           NA   NA  1 nanometer
# ...

# %%
n.edge_coords
# Out:
# array([[[476776., 146627., 170320.],
#         [476801., 146651., 170280.]],
#
#        [[438630., 136225., 196920.],
#         [438625., 136212., 196880.]],
#
#        [[442271., 140503., 196920.],
#         [442237., 140507., 196880.]],
#
#        ...,
#
#        [[455481., 242071.,  36480.],
#         [455286., 242316.,  36280.]],
#
#        [[461724., 228665.,  36160.],
#         [462272., 228704.,  35960.]],
#
#        [[461562., 228589.,  36280.],
#         [461724., 228665.,  36160.]]])

# %%
pymaid.get_neuron(16)
# Out:
# type                                 CatmaidNeuron
# name            Uniglomerular mALT VA6 adPN 017 DB
# id                                              16
# n_nodes                                      16840
# n_connectors                                  2158
# n_branches                                    1172
# n_leafs                                       1230
# cable_length                             4003108.5
# soma                                     [2941309]
# units                                  1 nanometer
# dtype: object

# %%
j=0
for i in range(2000):
    try:
        n=pymaid.get_neuron(i)
        j=j+1
        pymaid.clear_cache()
    except:
        continue
# Out:
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)
# INFO  : Cached cleared. (pymaid)

# %%
j
# Out:
# 8

# %%
help(pymaid.CatmaidInstance)
# Out:
# Help on class CatmaidInstance in module pymaid.client:
#
# class CatmaidInstance(builtins.object)
#  |  CatmaidInstance(server, api_token, http_user=None, http_password=None, project_id=1, max_threads=10, make_global=True, caching=True)
#  |
#  |  Class representing connection to a CATMAID project.
#  |
#  |  Holds base url, credentials and project ID. Fetches data and takes care of
#  |  caching results. When initialised, a CatmaidInstance is made the "global"
#  |  default connection for fetching data (see ``set_global`` argument).
#  |  Alternatively, pymaid functions accept a ``remote_instance`` argument that
#  |  lets you pass a CatmaidInstance explicitly.
#  |
#  |  Attributes
#  |  ----------
#  |  server :        str
#  |                  The url for a CATMAID server.
#  |  api_token :     str | None
#  |                  API token - see CATMAID `documentation <https://catmaid.
#  |                  readthedocs.io/en/stable/api.html#api-token>`_ on how to
# ...
