# %%
x_sources1=10
x_sources2=20
x_sources3=30
x_sources4=40
x_sources5=50

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d=10

# %%
x=np.arange(0,60,0.1)

# %%
d1=[np.sqrt(d*d+(i-x_sources1)*(i-x_sources1)) for i in x]
d2=[np.sqrt(d*d+(i-x_sources2)*(i-x_sources2)) for i in x]
d3=[np.sqrt(d*d+(i-x_sources3)*(i-x_sources3)) for i in x]
d4=[np.sqrt(d*d+(i-x_sources4)*(i-x_sources4)) for i in x]
d5=[np.sqrt(d*d+(i-x_sources5)*(i-x_sources5)) for i in x]

# %%
plt.plot(d1)

# %%
I1=np.array([1/(i*i) for i in d1])
I2=np.array([1/(i*i) for i in d2])
I3=np.array([1/(i*i) for i in d3])
I4=np.array([1/(i*i) for i in d4])
I5=np.array([1/(i*i) for i in d5])

# %%
I=I1+I2+I3+I4+I5

# %%
plt.plot(I)

# %%
d1=[np.sqrt(d*d+(i-x_sources1)*(i-x_sources1)) for i in x]
